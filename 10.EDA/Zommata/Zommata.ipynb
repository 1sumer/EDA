# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Python\10.EDA\Zommata\Zomato_df.csv")

# %%
df.dropna()
# Out:
#        Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 0               0             1           1   4.1    775         1         20
# 1               1             1           0   4.1    787         1         20
# 2               2             1           0   3.8    918         1         16
# 3               3             0           0   3.7     88         1         62
# 4               4             0           0   3.8    166         4         20
# ...           ...           ...         ...   ...    ...       ...        ...
# 23243       23243             1           1   3.8    128        84          5
# 23244       23244             0           0   3.9     77        84         38
# 23245       23245             0           0   2.8    161        84         21
# 23246       23246             0           0   2.5     81        84         21
# 23247       23247             0           1   4.3    236        25          4
#
#        cuisines    cost  menu_item
# 0          1386   800.0       5047
# 1           594   800.0       5047
# 2           484   800.0       5047
# 3          1587   300.0       5047
# 4          1406   600.0       5047
# ...         ...     ...        ...
# 23243      1318  1200.0       5047
# 23244       878  2000.0       5047
# 23245       539  1200.0       5047
# 23246        80   800.0       5047
# 23247       878  2500.0       5047
#
# [23248 rows x 10 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 23243       23243             1           1   3.8    128        84          5
# 23244       23244             0           0   3.9     77        84         38
# 23245       23245             0           0   2.8    161        84         21
# 23246       23246             0           0   2.5     81        84         21
# 23247       23247             0           1   4.3    236        25          4
#
#        cuisines    cost  menu_item
# 23243      1318  1200.0       5047
# 23244       878  2000.0       5047
# 23245       539  1200.0       5047
# 23246        80   800.0       5047
# 23247       878  2500.0       5047

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'online_order', 'book_table', 'rate', 'votes', 'location',
#        'rest_type', 'cuisines', 'cost', 'menu_item'],
#       dtype='object')

# %%
df.shape
# Out:
# (23248, 10)

# %%
columns_lst=list(df.columns)
for i in columns_lst:
    print('Number of unique values in',i, 'is',df[i].nunique())
# Out:
# Number of unique values in Unnamed: 0 is 23248
# Number of unique values in online_order is 2
# Number of unique values in book_table is 2
# Number of unique values in rate is 31
# Number of unique values in votes is 2303
# Number of unique values in location is 88
# Number of unique values in rest_type is 73
# Number of unique values in cuisines is 1681
# Number of unique values in cost is 57
# Number of unique values in menu_item is 5048

# %%
df.describe()
# Out:
#          Unnamed: 0  online_order    book_table          rate         votes  \
# count  23248.000000  23248.000000  23248.000000  23248.000000  23248.000000
# mean   11623.500000      0.704491      0.260539      3.905781    605.461674
# std     6711.263865      0.456281      0.438938      0.426153   1113.706789
# min        0.000000      0.000000      0.000000      1.800000      0.000000
# 25%     5811.750000      0.000000      0.000000      3.800000    104.000000
# 50%    11623.500000      1.000000      0.000000      4.000000    225.000000
# 75%    17435.250000      1.000000      1.000000      4.200000    597.000000
# max    23247.000000      1.000000      1.000000      4.900000  16832.000000
#
#            location     rest_type      cuisines          cost     menu_item
# count  23248.000000  23248.000000  23248.000000  23248.000000  23248.000000
# mean      35.525680     32.933672    862.081168    753.500946   4308.031487
# std       23.260984     20.506963    473.466781    520.472169   1394.280280
# min        0.000000      0.000000      0.000000     40.000000      0.000000
# 25%       19.000000     20.000000    429.000000    400.000000   4320.750000
# 50%       34.000000     21.000000    879.000000    600.000000   5047.000000
# 75%       49.000000     62.000000   1218.000000   1000.000000   5047.000000
# max       87.000000     72.000000   1680.000000   6000.000000   5047.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23248 entries, 0 to 23247
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    23248 non-null  int64
#  1   online_order  23248 non-null  int64
#  2   book_table    23248 non-null  int64
#  3   rate          23248 non-null  float64
#  4   votes         23248 non-null  int64
#  5   location      23248 non-null  int64
#  6   rest_type     23248 non-null  int64
#  7   cuisines      23248 non-null  int64
#  8   cost          23248 non-null  float64
#  9   menu_item     23248 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.8 MB

# %%
rate_mean = df['rate'].mean()
rate_mean
# Out:
# 3.905781142463868

# %%
plt.figure(figsize=(10,20))
for i in range(len(columns_lst)):
    plt.subplot(5,3,i+1)
    plt.title(columns_lst[i])
    plt.xticks(rotation=45)
    plt.hist(df[columns_lst[i]])
    
plt.tight_layout()

# %%
RATING = df['rate'].value_counts()
RATING
# Out:
# rate
# 3.9    3246
# 4.0    2902
# 4.1    2827
# 3.8    2483
# 4.2    2124
# 4.3    1680
# 3.7    1646
# 4.4    1142
# 3.6     878
# 4.5     648
# 3.5     482
# 3.4     351
# 2.8     321
# 2.9     313
# 3.1     307
# 4.6     300
# 3.0     291
# 3.2     250
# 3.3     219
# 2.7     190
# 4.7     167
# 2.6     138
# 4.8      66
# 2.5      57
# 4.9      55
# 2.4      54
# 2.3      45
# 2.2      26
# 2.1      24
# 2.0      11
# 1.8       5
# Name: count, dtype: int64

# %%
RATING.plot(kind='pie',radius=2)
plt.title('rating')
# Out:
# Text(0.5, 1.0, 'rating')

# %%
PLT = df[df['rate']==3.9].value_counts()[:20]
sns.set_style(style='whitegrid')
plt.figure(figsize=(5,5))
sns.distplot(PLT, label='Rate', color='tomato', kde=True)
plt.title('RATING')
plt.legend(loc=1)
plt.grid()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10068\615703234.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(PLT, label='Rate', color='tomato', kde=True)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)

# %%
df[df['rate']==3.9]
# Out:
#        Unnamed: 0  online_order  book_table  rate  votes  location  rest_type  \
# 15             15             1           0   3.9    133         1         13
# 17             17             0           0   3.9     93         1         13
# 24             24             1           0   3.9    172         1         29
# 26             26             1           0   3.9    230         1         29
# 30             30             1           0   3.9    286         1         62
# ...           ...           ...         ...   ...    ...       ...        ...
# 23216       23216             0           0   3.9     77        84         38
# 23230       23230             1           1   3.9    578        84         47
# 23236       23236             0           0   3.9     74        84         21
# 23241       23241             1           1   3.9    548        84         60
# 23244       23244             0           0   3.9     77        84         38
#
#        cuisines    cost  menu_item
# 15          441   800.0       5047
# 17          456   300.0       5047
# 24         1465   750.0       5047
# 26          235   650.0       5047
# 30          322   500.0       5047
# ...         ...     ...        ...
# 23216       878  2000.0       5047
# 23230       663  1000.0       5047
# 23236      1441  1200.0       5047
# 23241       880  1500.0       5047
# 23244       878  2000.0       5047
#
# [3246 rows x 10 columns]

# %%
df_su = pd.DataFrame(df.groupby('votes')['votes'].count())
df_su
# Out:
#        votes
# votes
# 0          4
# 8         10
# 9          4
# 10        11
# 25         7
# ...      ...
# 14723      3
# 14726      1
# 14956      2
# 16345      3
# 16832      3
#
# [2303 rows x 1 columns]

# %%
df_hu = df.groupby('votes')['votes'].count()[:50]
sns.countplot(df_hu,label='Votes', color='tomato')
plt.title('Votes')
plt.legend(loc=1)
plt.grid()

# %%
sns.set_style(style='whitegrid')
plt.figure(figsize=(5,5))
sns.histplot(df['votes'], label='Votes', color='tomato', kde=True)
plt.title('Votes')
plt.legend(loc=1)
plt.grid()

# %%
plt.figure(figsize=(5,5))
sns.histplot(df['rate'], color='greenyellow', label='RATE',kde=True)
plt.legend()
plt.grid()

# %%
df['cuisines']
# Out:
# 0        1386
# 1         594
# 2         484
# 3        1587
# 4        1406
#          ...
# 23243    1318
# 23244     878
# 23245     539
# 23246      80
# 23247     878
# Name: cuisines, Length: 23248, dtype: int64

# %%
sns.histplot(data=df, x='cost', hue='online_order')
# Out:
# <Axes: xlabel='cost', ylabel='Count'>
